# %% [markdown]
# # **Homework 1: COVID-19 Cases Prediction (Regression)**

# %% [markdown]
# Author: Heng-Jui Chang
#
# Slides: https://github.com/ga642381/ML2021-Spring/blob/main/HW01/HW01.pdf
# Videos (Mandarin): https://cool.ntu.edu.tw/courses/4793/modules/items/172854
# https://cool.ntu.edu.tw/courses/4793/modules/items/172853
# Video (English): https://cool.ntu.edu.tw/courses/4793/modules/items/176529
#
#
# Objectives:
# * Solve a regression problem with deep neural networks (DNN).
# * Understand basic DNN training tips.
# * Get familiar with PyTorch.
#
# If any questions, please contact the TAs via TA hours, NTU COOL, or email.

# %% [markdown]
# # **Download Data**
#
#
# If the Google drive links are dead, you can download data from [kaggle](https://www.kaggle.com/c/ml2021spring-hw1/data), and upload data manually to the workspace.

# %% [markdown]
# # **Import Some Packages**

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF
# To: /content/covid.train.csv
# 100% 2.00M/2.00M [00:00<00:00, 14.8MB/s]
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1CE240jLm2npU-tdz81-oVKEF3T2yfT1O
# To: /content/covid.test.csv
# 100% 651k/651k [00:00<00:00, 8.65MB/s]

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 42069  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # **Some Utilities**
#
# You do not need to modify this part.

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# # **Preprocess**
#
# We have three kinds of datasets:
# * `train`: for training
# * `dev`: for validation
# * `test`: for testing (w/o target value)

# %% [markdown]
# ## **Dataset**
#
# The `COVID19Dataset` below does:
# * read `.csv` files
# * extract features
# * split `covid.train.csv` into train/dev sets
# * normalize features
#
# Finishing `TODO` below might make you pass medium baseline.

# %%
class COVID19Dataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 path,
                 mode='train',
                 target_only=False):
        self.mode = mode

        # Read data into numpy arrays
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)

        if not target_only:
            feats = list(range(93))
        else:
            # TODO: Using 40 states & 2 tested_positive features (indices = 57 & 75)
            feats = list(range(40)) + [57, 75]

        if mode == 'test':
            # Testing data
            # data: 893 x 93 (40 states + day 1 (18) + day 2 (18) + day 3 (17))
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            # data: 2700 x 94 (40 states + day 1 (18) + day 2 (18) + day 3 (18))
            target = data[:, -1]
            data = data[:, feats]

            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 5 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 5 == 0]

            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features (you may remove this part to see what will happen)
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# ## **DataLoader**
#
# A `DataLoader` loads data from a given `Dataset` into batches.

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    ''' Generates a dataset, then is put into a dataloader. '''
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)  # Construct dataset
    dataloader = DataLoader(
        dataset,
        batch_size=config['batch_size'],
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)                            # Construct dataloader
    return dataloader

# %% [markdown]
# # **Deep Neural Network**
#
# `NeuralNet` is an `nn.Module` designed for regression.
# The DNN consists of 2 fully-connected layers with ReLU activation.
# This module also included a function `cal_loss` for calculating loss.

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim,config):
        super().__init__()
        # super(NeuralNet, self).__init__()
        # Define your neural network here
        # TODO: How to modify this model to achieve better performance?

        layers = []
        prev_dim = input_dim

        # 从 config 读 hidden layers

        for h in config['hidden_layers']:
            layers.append(nn.Linear(prev_dim, h))
            layers.append(nn.ReLU())
            prev_dim = h

        layers.append(nn.Linear(prev_dim, 1))

        self.net = nn.Sequential(*layers)

        self.criterion = nn.MSELoss()
        self.lambda_l2 = config['lambda_l2']





    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):

        ''' Calculate loss '''
        mse_loss = self.criterion(pred, target)


        l2_reg = 0

        for param in self.net.parameters():

            l2_reg += torch.norm(param, 2) ** 2

        loss = mse_loss + self.lambda_l2 * l2_reg
        # TODO: you may implement L1/L2 regularization here
        return self.criterion(pred, target)

# %% [markdown]
# # **Train/Dev/Test**

# %% [markdown]
# ## **Training**

# %%
def train(tr_set, dv_set, model, config, device):
    ''' DNN training '''

    n_epochs = config['n_epochs']  # Maximum number of epochs


    # Setup optimizer
    '''config['optimizer'] = 'AdamW'
    config['optim_hparas'] = {

    'weight_decay': 1e-4}'''
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        # After each epoch, test your model on the validation (development) set.
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## **Validation**

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## **Testing**

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# # **Setup Hyper-parameters**
#
# `config` contains hyper-parameters for training and the path to save your model.

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = True                   # TODO: Using 40 states & 2 tested_positive features

# TODO: How to tune these hyper-parameters to improve your model's performance?
config = {
    'n_epochs': 3000,                # maximum number of epochs
    'batch_size': 256,               # mini-batch size for dataloader
    'target_only': True,
    'hidden_layers':[128,64],
    'lambda_l2':1e-4,

    'optimizer': 'AdamW',              # optimization algorithm (optimizer in torch.optim) AdamW
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.0007,
        'weight_decay': 2e-4                             # learning rate of SGD
        #'momentum': 0.9              # momentum for SGD
    },
    'early_stop': 300,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# # **Load data and model**

# %%
tr_set = prep_dataloader(tr_path, 'train', config)
dv_set = prep_dataloader(tr_path, 'dev', config)
tt_set = prep_dataloader(tt_path, 'test', config)
# Out:
# Finished reading the train set of COVID19 Dataset (2160 samples found, each dim = 93)
# Finished reading the dev set of COVID19 Dataset (540 samples found, each dim = 93)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 93)

# %%
model = NeuralNet(tr_set.dataset.dim, config).to(device)  # Construct model and move to device

# %% [markdown]
# # **Start Training!**

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 307.6332)
# Saving model (epoch =    2, loss = 278.4029)
# Saving model (epoch =    3, loss = 228.8198)
# Saving model (epoch =    4, loss = 157.6813)
# Saving model (epoch =    5, loss = 81.1019)
# Saving model (epoch =    6, loss = 37.2776)
# Saving model (epoch =    7, loss = 33.8032)
# Saving model (epoch =    8, loss = 27.8244)
# Saving model (epoch =    9, loss = 23.8738)
# Saving model (epoch =   10, loss = 22.3480)
# Saving model (epoch =   11, loss = 20.5106)
# Saving model (epoch =   12, loss = 19.0670)
# Saving model (epoch =   13, loss = 17.7391)
# Saving model (epoch =   14, loss = 16.4698)
# Saving model (epoch =   15, loss = 15.3130)
# Saving model (epoch =   16, loss = 14.2482)
# Saving model (epoch =   17, loss = 13.2075)
# Saving model (epoch =   18, loss = 12.2755)
# Saving model (epoch =   19, loss = 11.4188)
# Saving model (epoch =   20, loss = 10.6450)
# Saving model (epoch =   21, loss = 9.8440)
# Saving model (epoch =   22, loss = 9.1259)
# Saving model (epoch =   23, loss = 8.4434)
# Saving model (epoch =   24, loss = 7.8090)
# Saving model (epoch =   25, loss = 7.2011)
# Saving model (epoch =   26, loss = 6.6164)
# Saving model (epoch =   27, loss = 6.1082)
# Saving model (epoch =   28, loss = 5.6155)
# Saving model (epoch =   29, loss = 5.1990)
# Saving model (epoch =   30, loss = 4.8047)
# Saving model (epoch =   31, loss = 4.4742)
# Saving model (epoch =   32, loss = 4.1424)
# Saving model (epoch =   33, loss = 3.8713)
# Saving model (epoch =   34, loss = 3.6687)
# Saving model (epoch =   35, loss = 3.4543)
# Saving model (epoch =   36, loss = 3.2833)
# Saving model (epoch =   37, loss = 3.1236)
# Saving model (epoch =   38, loss = 2.9894)
# Saving model (epoch =   39, loss = 2.8896)
# Saving model (epoch =   40, loss = 2.7680)
# Saving model (epoch =   41, loss = 2.6631)
# Saving model (epoch =   42, loss = 2.5738)
# Saving model (epoch =   43, loss = 2.4816)
# Saving model (epoch =   44, loss = 2.4144)
# Saving model (epoch =   45, loss = 2.3444)
# Saving model (epoch =   46, loss = 2.2776)
# Saving model (epoch =   47, loss = 2.2122)
# Saving model (epoch =   48, loss = 2.1719)
# Saving model (epoch =   49, loss = 2.1194)
# Saving model (epoch =   50, loss = 2.0923)
# Saving model (epoch =   51, loss = 2.0402)
# Saving model (epoch =   52, loss = 2.0069)
# Saving model (epoch =   53, loss = 1.9627)
# Saving model (epoch =   54, loss = 1.9321)
# Saving model (epoch =   55, loss = 1.8997)
# Saving model (epoch =   56, loss = 1.8650)
# Saving model (epoch =   57, loss = 1.8347)
# Saving model (epoch =   58, loss = 1.8112)
# Saving model (epoch =   59, loss = 1.7738)
# Saving model (epoch =   60, loss = 1.7604)
# Saving model (epoch =   61, loss = 1.7321)
# Saving model (epoch =   62, loss = 1.7080)
# Saving model (epoch =   63, loss = 1.6758)
# Saving model (epoch =   64, loss = 1.6626)
# Saving model (epoch =   65, loss = 1.6566)
# Saving model (epoch =   66, loss = 1.6347)
# Saving model (epoch =   67, loss = 1.6052)
# Saving model (epoch =   68, loss = 1.5910)
# Saving model (epoch =   69, loss = 1.5713)
# Saving model (epoch =   70, loss = 1.5561)
# Saving model (epoch =   71, loss = 1.5506)
# Saving model (epoch =   72, loss = 1.5310)
# Saving model (epoch =   73, loss = 1.5025)
# Saving model (epoch =   74, loss = 1.5015)
# Saving model (epoch =   75, loss = 1.4751)
# Saving model (epoch =   76, loss = 1.4646)
# Saving model (epoch =   77, loss = 1.4508)
# Saving model (epoch =   78, loss = 1.4348)
# Saving model (epoch =   79, loss = 1.4328)
# Saving model (epoch =   80, loss = 1.4010)
# Saving model (epoch =   82, loss = 1.3962)
# Saving model (epoch =   83, loss = 1.3765)
# Saving model (epoch =   84, loss = 1.3714)
# Saving model (epoch =   85, loss = 1.3470)
# Saving model (epoch =   86, loss = 1.3391)
# Saving model (epoch =   88, loss = 1.3256)
# Saving model (epoch =   89, loss = 1.3155)
# Saving model (epoch =   91, loss = 1.3015)
# Saving model (epoch =   92, loss = 1.2853)
# Saving model (epoch =   93, loss = 1.2820)
# Saving model (epoch =   94, loss = 1.2720)
# Saving model (epoch =   96, loss = 1.2474)
# Saving model (epoch =   98, loss = 1.2353)
# Saving model (epoch =   99, loss = 1.2198)
# Saving model (epoch =  101, loss = 1.2011)
# Saving model (epoch =  103, loss = 1.1965)
# Saving model (epoch =  105, loss = 1.1927)
# Saving model (epoch =  106, loss = 1.1827)
# Saving model (epoch =  107, loss = 1.1756)
# Saving model (epoch =  108, loss = 1.1668)
# Saving model (epoch =  109, loss = 1.1534)
# Saving model (epoch =  112, loss = 1.1483)
# Saving model (epoch =  113, loss = 1.1297)
# Saving model (epoch =  115, loss = 1.1274)
# Saving model (epoch =  116, loss = 1.1243)
# Saving model (epoch =  117, loss = 1.1203)
# Saving model (epoch =  118, loss = 1.1170)
# Saving model (epoch =  120, loss = 1.0951)
# Saving model (epoch =  125, loss = 1.0917)
# Saving model (epoch =  126, loss = 1.0732)
# Saving model (epoch =  127, loss = 1.0683)
# Saving model (epoch =  128, loss = 1.0635)
# Saving model (epoch =  130, loss = 1.0455)
# Saving model (epoch =  132, loss = 1.0420)
# Saving model (epoch =  134, loss = 1.0373)
# Saving model (epoch =  135, loss = 1.0370)
# Saving model (epoch =  137, loss = 1.0358)
# Saving model (epoch =  138, loss = 1.0217)
# Saving model (epoch =  140, loss = 1.0113)
# Saving model (epoch =  142, loss = 1.0038)
# Saving model (epoch =  144, loss = 0.9939)
# Saving model (epoch =  146, loss = 0.9925)
# Saving model (epoch =  148, loss = 0.9793)
# Saving model (epoch =  150, loss = 0.9774)
# Saving model (epoch =  152, loss = 0.9759)
# Saving model (epoch =  156, loss = 0.9573)
# Saving model (epoch =  157, loss = 0.9478)
# Saving model (epoch =  163, loss = 0.9444)
# Saving model (epoch =  165, loss = 0.9319)
# Saving model (epoch =  168, loss = 0.9232)
# Saving model (epoch =  172, loss = 0.9173)
# Saving model (epoch =  175, loss = 0.9000)
# Saving model (epoch =  180, loss = 0.8892)
# Saving model (epoch =  189, loss = 0.8872)
# Saving model (epoch =  190, loss = 0.8871)
# Saving model (epoch =  191, loss = 0.8668)
# Saving model (epoch =  194, loss = 0.8657)
# Saving model (epoch =  195, loss = 0.8569)
# Saving model (epoch =  201, loss = 0.8486)
# Saving model (epoch =  204, loss = 0.8413)
# Saving model (epoch =  207, loss = 0.8353)
# Saving model (epoch =  213, loss = 0.8348)
# Saving model (epoch =  217, loss = 0.8259)
# Saving model (epoch =  219, loss = 0.8251)
# Saving model (epoch =  221, loss = 0.8218)
# Saving model (epoch =  223, loss = 0.8137)
# Saving model (epoch =  231, loss = 0.8101)
# Saving model (epoch =  239, loss = 0.8099)
# Saving model (epoch =  240, loss = 0.8087)
# Saving model (epoch =  241, loss = 0.8045)
# Saving model (epoch =  243, loss = 0.8029)
# Saving model (epoch =  246, loss = 0.7994)
# Saving model (epoch =  248, loss = 0.7923)
# Saving model (epoch =  250, loss = 0.7896)
# Saving model (epoch =  252, loss = 0.7798)
# Saving model (epoch =  269, loss = 0.7792)
# Saving model (epoch =  273, loss = 0.7686)
# Saving model (epoch =  283, loss = 0.7686)
# Saving model (epoch =  291, loss = 0.7630)
# Saving model (epoch =  292, loss = 0.7532)
# Saving model (epoch =  299, loss = 0.7522)
# Saving model (epoch =  320, loss = 0.7505)
# Saving model (epoch =  333, loss = 0.7408)
# Saving model (epoch =  367, loss = 0.7340)
# Saving model (epoch =  399, loss = 0.7273)
# Saving model (epoch =  430, loss = 0.7202)
# Saving model (epoch =  454, loss = 0.7156)
# Saving model (epoch =  525, loss = 0.7144)
# Saving model (epoch =  571, loss = 0.7081)
# Saving model (epoch =  753, loss = 0.7068)
# Saving model (epoch =  784, loss = 0.7014)
# Saving model (epoch =  797, loss = 0.6990)
# Saving model (epoch =  874, loss = 0.6969)
# Saving model (epoch =  879, loss = 0.6849)
# Saving model (epoch =  957, loss = 0.6836)
# Finished training after 1258 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim, config).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# # **Testing**
# The predictions of your model on testing set will be stored at `pred.csv`.

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'pred.csv')         # save prediction file to pred.csv
# Out:
# Saving results to pred.csv

# %% [markdown]
# # **Hints**
#
# ## **Simple Baseline**
# * Run sample code
#
# ## **Medium Baseline**
# * Feature selection: 40 states + 2 `tested_positive` (`TODO` in dataset)
#
# ## **Strong Baseline**
# * Feature selection (what other features are useful?)
# * DNN architecture (layers? dimension? activation function?)
# * Training (mini-batch? optimizer? learning rate?)
# * L2 regularization
# * There are some mistakes in the sample code, can you find them?

# %% [markdown]
# # **Reference**
# This code is completely written by Heng-Jui Chang @ NTUEE.
# Copying or reusing this code is required to specify the original author.
#
# E.g.
# Source: Heng-Jui Chang @ NTUEE (https://github.com/ga642381/ML2021-Spring/blob/main/HW01/HW01.ipynb)
